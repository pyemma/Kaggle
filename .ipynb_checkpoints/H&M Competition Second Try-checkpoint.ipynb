# %%
import numpy as np
import pandas as pd
import time
import pickle

from collections import Counter

# %%
train = pd.read_csv("h-and-m-personalized-fashion-recommendations/transactions_train.csv")

# %%
train['customer_id'] = train['customer_id'].str[-16:].apply(lambda x: int(x, 16)).astype('int64')
train['article_id'] = train.article_id.astype('int32')
train.t_dat = pd.to_datetime(train.t_dat)
train = train[['t_dat','customer_id','article_id']]

# %%
sub_train = train.sample(frac=0.1)

# %%
agg_articles = sub_train.groupby('customer_id')['article_id'].apply(list).reset_index(name='agg_articles')

# %%
cnt = Counter()

for _, row in agg_articles.iterrows():    
    articles = row['agg_articles']
    for i in range(0, len(articles) - 1):
        for j in range(i+1, len(articles)):
            a1, a2 = articles[i], articles[j]
            if a1 not in cnt:
                cnt[a1] = Counter()
            if a2 not in cnt:
                cnt[a2] = Counter()
            
            cnt[a1][a2] += 1
            cnt[a2][a1] += 1

# %%
most_common_purchase = {}

for a1, articles in cnt.items():
    li = [(i, j) for (i, j) in articles.items()]
    li = sorted(li, key=lambda x: x[1], reverse=True)
    
    li = li[: min(len(li), 7)]
    
    most_common_purchase[a1] = li
    
most_common_purchase

# %% [markdown]
# In the below cells, we compute the frequent item that is commonly purchased together

# %%
agg_total = train.groupby('customer_id')['article_id'].apply(list).reset_index(name='agg_articles')

# %%
cnt = Counter()
start = time.time()

for idx, row in agg_total.iterrows():
    articles = row['agg_articles']
    for i in range(0, len(articles) - 1):
        for j in range(i+1, len(articles)):
            a1, a2 = articles[i], articles[j]
            if a1 not in cnt:
                cnt[a1] = Counter()
            if a2 not in cnt:
                cnt[a2] = Counter()
            
            cnt[a1][a2] += 1
            cnt[a2][a1] += 1
    
    if idx % 10000 == 0:
        end = time.time()
        print(f"Row {idx} processed")
        print(f"Time passed {end - start}")
        print(f"Current size of the cnt {len(cnt)}")
        start = time.time()

# %%
import pickle

with open('most_common_purchase.pkl', 'wb') as file:
    pickle.dump(most_common_purchase_new, file)

# %% [raw]
# with open('most_common_purchase.pkl', 'rb') as file:
#     res = pickle.load(file)

# %%
most_common_purchase = {}

for a1, articles in cnt.items():
    li = [(i, j) for (i, j) in articles.items()]
    li = sorted(li, key=lambda x: x[1], reverse=True)
    
    li = li[: min(len(li), 3)]
    
    most_common_purchase[a1] = li

# %% [markdown]
# In the below cells, we compute the last purchased item from last week

# %%
sub_train = train.sample(frac=0.1)
tmp = sub_train.groupby('customer_id').t_dat.max().reset_index()
tmp.columns = ['customer_id', 'max_dat']
sub_train = sub_train.merge(tmp, on=['customer_id'], how='left')
sub_train['diff_dat'] = (sub_train.max_dat - sub_train.t_dat).dt.days
sub_train = sub_train.loc[sub_train['diff_dat'] <= 6]

# %%
df = pd.read_csv('h-and-m-personalized-fashion-recommendations/transactions_train.csv')

# %%
articles = df.article_id.value_counts()

# %%
most_common_purchase_items = {
    key: [x[0] for x in val] for key, val in most_common_purchase.items()
}

# %%
sub_train['most_common_articles'] = sub_train.article_id.map(most_common_purchase_items)

# %%
most_common_purchase_new = {
    key: [elem for elem in val if elem[0] != key] for key, val in most_common_purchase.items()
}

# %%
most_common_purchase_new
# Out:
# {657510001: [(706016001, 398),
#   (706016002, 220),
#   (677711003, 208),
#   (372860001, 190),
#   (448509014, 182),
#   (156231001, 181)],
#  539723001: [(706016001, 7638),
#   (539723005, 2661),
#   (562245050, 2197),
#   (706016002, 2163),
#   (399223001, 1320),
#   (539723003, 1263)],
#  739373004: [(706016001, 65),
#   (739373001, 50),
#   (759871002, 45),
#   (399223001, 44),
#   (706016002, 43),
#   (372860001, 41)],
#  806012001: [(773955001, 328),
#   (706016001, 277),
#   (610776002, 178),
#   (562245046, 161),
#   (759871002, 155),
#   (706016002, 152)],
#  706016001: [(706016002, 26421),
#   (706016003, 16038),
#   (706016015, 12531),
#   (706016006, 10746),
#   (399223001, 9125),
#   (554450001, 7914)],
#  568597006: [(568601006, 4845),
#   (695544001, 4037),
#   (568597007, 1766),
#   (751471001, 1635),
#   (573716012, 1163),
#   (524825011, 1134)],
#  849493006: [(849493007, 90),
#   (877224007, 76),
#   (855793005, 53),
#   (851802001, 48),
#   (751471001, 47),
#   (608945001, 44)],
#  873657001: [(706016001, 26),
#   (111586001, 25),
#   (759871002, 24),
#   (156231001, 18),
#   (372860001, 16),
#   (772902001, 14)],
#  673396002: [(706016001, 2988),
#   (706016002, 1908),
#   (759871002, 1441),
#   (706016003, 1229),
#   (448509014, 1227),
#   (610776002, 1208)],
#  812167004: [(812167002, 402),
#   (706016001, 225),
#   (762205003, 213),
#   (762205001, 209),
#   (812167003, 173),
#   (751471001, 166)],
#  687114002: [(685968001, 27),
#   (687114001, 24),
#   (111586001, 19),
#   (572797001, 18),
#   (686744001, 17),
#   (685969001, 16)],
#  670655001: [(670655002, 431),
#   (448509014, 244),
#   (706016001, 243),
#   (689931001, 212),
#   (156231001, 182),
#   (562245001, 160)],
#  671613001: [(671622001, 96),
#   (297078001, 96),
#   (297078002, 94),
#   (201219011, 56),
#   (201219003, 45),
#   (201219012, 41)],
#  661162002: [(706016001, 125),
#   (661162004, 98),
#   (661162003, 91),
#   (562245046, 84),
#   (661162001, 78),
#   (673677002, 71)],
#  661162003: [(661162002, 91),
#   (673677002, 74),
#   (661162001, 69),
#   (671973002, 56),
#   (673677003, 51),
#   (562245001, 48)],
#  671515003: [(671515001, 293),
#   (706016001, 224),
#   (537116001, 208),
#   (706016003, 138),
#   (563519001, 136),
#   (706016002, 134)],
#  663015005: [(160442007, 76),
#   (706016001, 45),
#   (663015002, 43),
#   (464297007, 42),
#   (179123001, 39),
#   (610776002, 38)],
#  637515005: [(637515011, 208),
#   (706016001, 193),
#   (637515004, 167),
#   (610776002, 152),
#   (637515002, 146),
#   (637515003, 135)],
#  688873006: [(688873001, 419),
#   (688873005, 315),
#   (695632001, 283),
#   (688873007, 279),
#   (688873002, 249),
#   (610776002, 220)],
#  663236004: [(678342001, 579),
#   (561445005, 88),
#   (673677002, 77),
#   (706016001, 76),
#   (160442007, 66),
#   (399223001, 65)],
#  714582006: [(714582001, 105),
#   (519583013, 79),
#   (706016001, 64),
#   (714582002, 62),
#   (714582005, 61),
#   (573716012, 60)],
#  670424001: [(651584005, 186),
#   (670424002, 179),
#   (673677002, 158),
#   (610776002, 117),
#   (706016001, 116),
#   (448509014, 106)],
#  670424002: [(670424001, 179),
#   (706016001, 112),
#   (677049001, 89),
#   (372860001, 77),
#   (706016002, 76),
#   (610776001, 70)],
#  681002003: [(706016002, 44),
#   (579541001, 44),
#   (111586001, 43),
#   (519583013, 41),
#   (681002002, 39),
#   (562245001, 39)],
#  678558002: [(678558001, 83),
#   (678558004, 73),
#   (717664003, 52),
#   (738305001, 40),
#   (706016001, 37),
#   (160442010, 37)],
#  688873003: [(688873002, 409),
#   (695632002, 399),
#   (688873007, 357),
#   (688873004, 354),
#   (695632001, 339),
#   (688873011, 275)],
#  695545005: [(695545001, 365),
#   (695545008, 341),
#   (695545002, 305),
#   (706016001, 286),
#   (573716012, 272),
#   (678942001, 267)],
#  695545008: [(695545005, 341),
#   (679853009, 318),
#   (695545001, 310),
#   (695545002, 240),
#   (573716012, 201),
#   (706016001, 201)],
#  695545007: [(695545001, 1298),
#   (573716012, 763),
#   (695545002, 701),
#   (573716050, 306),
#   (562245001, 269),
#   (610776002, 268)],
#  695632002: [(695632001, 3243),
#   (706016001, 1440),
#   (695632003, 1152),
#   (568601006, 1131),
#   (762846001, 999),
#   (751471001, 950)],
#  649671009: [(649671002, 59),
#   (695545005, 39),
#   (673677002, 39),
#   (610776001, 39),
#   (678942001, 38),
#   (610776002, 34)],
#  695632025: [(695632002, 235),
#   (695632001, 178),
#   (695632003, 135),
#   (655784001, 119),
#   (615141002, 116),
#   (706363001, 104)],
#  738182002: [(678342001, 578),
#   (738182001, 140),
#   (561445005, 98),
#   (583534009, 79),
#   (678942001, 58),
#   (565379001, 52)],
#  583534014: [(696678004, 346),
#   (583534013, 267),
#   (583534009, 182),
#   (583534002, 138),
#   (583534018, 110),
#   (696678006, 107)],
#  743014004: [(743014003, 185),
#   (610776002, 156),
#   (678942001, 86),
#   (610776001, 82),
#   (732418001, 55),
#   (625939003, 54)],
#  717673002: [(717673001, 69),
#   (749699002, 30),
#   (751530003, 30),
#   (583534014, 27),
#   (740824005, 27),
#   (751530004, 27)],
#  576661003: [(608945001, 30),
#   (576661008, 22),
#   (568478001, 21),
#   (576661009, 18),
#   (706016001, 18),
#   (568478003, 18),
#   (299841004, 15)],
#  629975001: [(685813008, 8),
#   (570004010, 7),
#   (699924001, 6),
#   (575347003, 6),
#   (689365048, 6),
#   (160442007, 6)],
#  576661008: [(576661009, 170),
#   (576661011, 159),
#   (576661015, 76),
#   (519583008, 43),
#   (630084003, 42),
#   (768912001, 40)],
#  583534009: [(583534002, 809),
#   (583534013, 469),
#   (706016001, 355),
#   (610776002, 353),
#   (803757001, 281),
#   (610776001, 266)],
#  675068002: [(507910001, 767),
#   (706016001, 645),
#   (762846001, 617),
#   (675068003, 608),
#   (695632002, 599),
#   (507909001, 525)],
#  675068003: [(675068002, 608),
#   (507910001, 208),
#   (762846001, 205),
#   (108775044, 171),
#   (675068001, 165),
#   (706016001, 139)],
#  695544009: [(751471001, 134),
#   (678942001, 123),
#   (695544005, 113),
#   (714996001, 112),
#   (695544002, 112),
#   (573716012, 111)],
#  583534018: [(583534013, 186),
#   (696678005, 157),
#   (666382014, 154),
#   (717059001, 151),
#   (687601002, 146),
#   (583534009, 142)],
#  519583013: [(519583033, 924),
#   (399256005, 819),
#   (562245001, 772),
#   (519583028, 619),
#   (556255001, 614),
#   (519583008, 611)],
#  695632015: [(695632001, 214),
#   (695632002, 210),
#   (706016001, 170),
#   (695632003, 169),
#   (695632010, 128),
#   (399223001, 116)],
#  401044032: [(401044004, 463),
#   (401044012, 262),
#   (401044002, 244),
#   (706016001, 111),
#   (543310001, 104),
#   (706016002, 93)],
#  401044002: [(401044004, 646),
#   (401044012, 326),
#   (401044032, 244),
#   (543310001, 205),
#   (706016001, 191),
#   (610776002, 178)],
#  685816006: [(685816002, 465),
#   (685816017, 408),
#   (685816004, 392),
#   (685816003, 376),
#   (685816001, 376),
#   (685816007, 334)],
#  685816017: [(685816002, 1173),
#   (685816001, 866),
#   (685816008, 755),
#   (685816024, 663),
#   (685816004, 657),
#   (685816007, 532)],
#  685816013: [(685816002, 134),
#   (685816001, 108),
#   (685816011, 93),
#   (685816017, 91),
#   (685816008, 90),
#   (685816007, 85),
#   (685816012, 81)],
#  685816011: [(685816002, 931),
#   (685816001, 831),
#   (685816008, 428),
#   (685816017, 371),
#   (685814001, 337),
#   (759871002, 262)],
#  579541031: [(579541001, 395),
#   (579541004, 218),
#   (579541030, 120),
#   (579541035, 105),
#   (579541026, 103),
#   (579541036, 89)],
#  579541004: [(579541001, 1991),
#   (568601007, 480),
#   (678942001, 412),
#   (579541075, 394),
#   (579541026, 389),
#   (610776001, 384)],
#  579541042: [(579541001, 627),
#   (579541026, 294),
#   (579541004, 287),
#   (579541052, 243),
#   (507909001, 220),
#   (579541011, 145)],
#  714996001: [(573716012, 179),
#   (751471001, 156),
#   (573716052, 132),
#   (562245050, 128),
#   (678942001, 128),
#   (783346001, 127)],
#  743594003: [(745475001, 308),
#   (745475002, 307),
#   (743594002, 245),
#   (610776002, 234),
#   (562245050, 215),
#   (706016001, 211)],
#  629381012: [(629381002, 327),
#   (629381001, 269),
#   (721320001, 147),
#   (706016001, 130),
#   (610776002, 100),
#   (179123001, 86)],
#  629381002: [(411413020, 1920),
#   (537116001, 1477),
#   (514817009, 1048),
#   (698328003, 963),
#   (629381001, 468),
#   (629381012, 327)],
#  665089007: [(665089001, 533),
#   (744712003, 260),
#   (696209007, 157),
#   (696209002, 127),
#   (689109001, 118),
#   (744712001, 114)],
#  665089001: [(665089007, 533),
#   (610776002, 329),
#   (610776001, 323),
#   (744712001, 293),
#   (665089008, 274),
#   (706016001, 270)],
#  734319002: [(734319001, 79),
#   (707082002, 36),
#   (772829002, 33),
#   (717779002, 28),
#   (813265001, 27),
#   (749699002, 27)],
#  733076004: [(733076002, 150),
#   (562245046, 78),
#   (706016001, 73),
#   (702790004, 60),
#   (464297007, 60),
#   (372860001, 58)],
#  716360001: [(751994001, 35),
#   (632982054, 29),
#   (852174003, 28),
#   (892280002, 26),
#   (519583013, 23),
#   (621381012, 23)],
#  786347002: [(786347001, 258),
#   (786347008, 153),
#   (706016001, 114),
#   (156231001, 108),
#   (803118002, 86),
#   (573716012, 86)],
#  779781003: [(568601033, 424),
#   (568597006, 109),
#   (568597007, 98),
#   (568601006, 96),
#   (568601007, 80),
#   (751471002, 77)],
#  753692001: [(753692004, 41),
#   (753692005, 31),
#   (579541001, 30),
#   (753692009, 29),
#   (399256005, 27),
#   (610776002, 27)],
#  753692005: [(753692001, 31),
#   (753692004, 27),
#   (572797001, 25),
#   (750424009, 23),
#   (598755001, 20),
#   (111586001, 19),
#   (579541001, 18)],
#  785018004: [(785018003, 423),
#   (785018002, 366),
#   (785018005, 235),
#   (706016001, 227),
#   (537116001, 184),
#   (706016002, 157)],
#  733098013: [(733098009, 175),
#   (733098008, 152),
#   (706016001, 143),
#   (733098011, 135),
#   (537116001, 133),
#   (673677002, 121)],
#  745250002: [(745250001, 407),
#   (745250003, 197),
#   (706016001, 139),
#   (796210001, 112),
#   (739953003, 102),
#   (399256001, 101)],
#  785018002: [(785018003, 497),
#   (706016001, 367),
#   (785018004, 366),
#   (537116001, 285),
#   (706016002, 239),
#   (785018005, 237)],
#  745250003: [(745250001, 309),
#   (745250002, 197),
#   (706016001, 166),
#   (796210001, 139),
#   (562245001, 124),
#   (754262001, 104)],
#  792469001: [(719655001, 532),
#   (719957006, 507),
#   (372860001, 294),
#   (610776002, 278),
#   (706016001, 241),
#   (464297007, 223)],
#  719957009: [(719957006, 286),
#   (719957003, 118),
#   (706016001, 117),
#   (372860001, 109),
#   (706016002, 105),
#   (719655001, 100)],
#  809549002: [(809549001, 205),
#   (824148001, 94),
#   (764582002, 94),
#   (448509014, 88),
#   (729002003, 84),
#   (824148002, 81)],
#  662948012: [(706016001, 298),
#   (706016002, 217),
#   (662948013, 206),
#   (610776002, 192),
#   (156231001, 181),
#   (372860001, 178)],
#  705966005: [(705966002, 202),
#   (797710001, 165),
#   (706016001, 105),
#   (797710002, 100),
#   (705966006, 95),
#   (372860001, 70)],
#  739953002: [(739953001, 945),
#   (695545001, 792),
#   (739953003, 758),
#   (706016001, 474),
#   (697054014, 437),
#   (573716012, 380)],
#  739953003: [(739953002, 758),
#   (706016001, 426),
#   (739953001, 390),
#   (695545001, 377),
#   (562245001, 361),
#   (573716012, 347)],
#  794389002: [(794389001, 113),
#   (562245018, 76),
#   (562245046, 58),
#   (706016001, 49),
#   (562245001, 47),
#   (542402001, 46)],
#  739953001: [(739953002, 945),
#   (697054003, 430),
#   (739953003, 390),
#   (739953006, 388),
#   (706016001, 324),
#   (762846001, 308)],
#  790450001: [(695632002, 98),
#   (762846001, 84),
#   (572797002, 59),
#   (562245050, 58),
#   (706016003, 55),
#   (850917001, 52)],
#  814293009: [(835044007, 85),
#   (156231001, 62),
#   (814293003, 60),
#   (759871002, 55),
#   (847967001, 53),
#   (814293008, 48)],
#  768739003: [(719655001, 62),
#   (372860001, 57),
#   (719957006, 49),
#   (792469001, 48),
#   (372860002, 37),
#   (793108003, 37)],
#  762796003: [(762796001, 280),
#   (762796002, 205),
#   (762796004, 165),
#   (706016001, 161),
#   (372860001, 152),
#   (399223001, 120)],
#  771557008: [(771557004, 185),
#   (771557002, 136),
#   (316441001, 136),
#   (778064003, 134),
#   (678942001, 131),
#   (610776002, 110)],
#  700765005: [(700765001, 573),
#   (611415005, 432),
#   (736531006, 231),
#   (611415001, 208),
#   (827957002, 198),
#   (827957003, 168)],
#  768739001: [(719655001, 115),
#   (719957006, 83),
#   (702366001, 73),
#   (714176001, 73),
#   (792469001, 63),
#   (372860001, 57)],
#  801309010: [(706016001, 277),
#   (801309002, 254),
#   (662948013, 211),
#   (801309001, 204),
#   (706016002, 194),
#   (777434001, 186)],
#  770351002: [(770352002, 424),
#   (770351001, 88),
#   (770351005, 85),
#   (770351003, 80),
#   (678942001, 63),
#   (372860002, 62)],
#  809549001: [(706016001, 343),
#   (807174001, 264),
#   (759871002, 242),
#   (448509014, 231),
#   (780297001, 230),
#   (706016002, 225)],
#  770352002: [(770351002, 424),
#   (695632002, 60),
#   (179123001, 60),
#   (536139006, 57),
#   (759871002, 49),
#   (562245018, 47)],
#  801309002: [(706016001, 394),
#   (706016002, 298),
#   (801309001, 261),
#   (801309010, 254),
#   (759871002, 236),
#   (448509014, 213)],
#  762846008: [(762846006, 2000),
#   (762846001, 1934),
#   (697058005, 1585),
#   (706016001, 1421),
#   (762846007, 1148),
#   (751471001, 1004)],
#  831611001: [(831610001, 362),
#   (678942001, 83),
#   (610776002, 69),
#   (772773002, 58),
#   (664074001, 56),
#   (772934001, 56)],
#  655784014: [(655784001, 454),
#   (655784007, 204),
#   (796210010, 204),
#   (796210001, 173),
#   (783346001, 168),
#   (751471001, 151)],
#  827697001: [(856232002, 96),
#   (673396002, 75),
#   (818029001, 65),
#   (673677002, 64),
#   (712587003, 61),
#   (824185001, 61)],
#  824254001: [(568601006, 43),
#   (664074001, 36),
#   (562245046, 33),
#   (610776002, 33),
#   (610776001, 32),
#   (706016002, 31)],
#  831610001: [(831611001, 362),
#   (772773002, 93),
#   (772945001, 61),
#   (610776002, 55),
#   (678942001, 48),
#   (772934001, 44)],
#  779953002: [(148033001, 14),
#   (751994001, 14),
#   (716360001, 13),
#   (733700001, 11),
#   (774113006, 10),
#   (796210002, 9),
#   (519583013, 8)],
#  804536004: [(499334001, 15),
#   (729318001, 15),
#   (778064003, 13),
#   (148033006, 11),
#   (519583013, 10),
#   (337777001, 10),
#   (689011021, 10)],
#  828268001: [(751471001, 111),
#   (568601038, 99),
#   (828268002, 92),
#   (568601006, 83),
#   (673396002, 79),
#   (706016001, 78)],
#  828465002: [(706016001, 60),
#   (573716012, 41),
#   (853839001, 41),
#   (562245001, 37),
#   (706016002, 36),
#   (111586001, 36)],
#  709987008: [(709987009, 108),
#   (706016001, 90),
#   (673396002, 90),
#   (568601006, 82),
#   (751471001, 81),
#   (856440001, 76)],
#  859247004: [(859247003, 209),
#   (859247007, 162),
#   (706016001, 138),
#   (751471001, 88),
#   (537116001, 84),
#   (562245046, 81)],
#  758513002: [(758513001, 28),
#   (751471001, 27),
#   (572797002, 21),
#   (706016001, 21),
#   (762846008, 20),
#   (718278001, 20)],
#  803118002: [(803118003, 448),
#   (635789001, 337),
#   (802779001, 300),
#   (678942001, 260),
#   (803118001, 253),
#   (688341001, 229)],
#  735439001: [(706016001, 143),
#   (678942001, 138),
#   (579541001, 104),
#   (179208001, 98),
#   (738731002, 85),
#   (706016002, 85)],
#  865122001: [(866837002, 94),
#   (844125002, 36),
#   (858280001, 35),
#   (691989004, 33),
#   (789390001, 31),
#   (156231001, 31)],
#  844115001: [(556260004, 30),
#   (856808006, 25),
#   (844118001, 23),
#   (861712001, 23),
#   (844104001, 22),
#   (569997012, 22)],
#  753692019: [(753692017, 51),
#   (753692018, 50),
#   (678942032, 42),
#   (766346003, 38),
#   (865532001, 34),
#   (817361002, 34)],
#  772565007: [(772565006, 41),
#   (706016001, 17),
#   (372860002, 17),
#   (695632002, 16),
#   (158340001, 16),
#   (372860001, 16)],
#  744806002: [(179123001, 35),
#   (399087010, 27),
#   (399087001, 25),
#   (680403001, 24),
#   (556255003, 24),
#   (519583013, 23),
#   (108775015, 21)],
#  753692018: [(753692017, 73),
#   (753692019, 50),
#   (706016001, 44),
#   (783346018, 43),
#   (399256001, 38),
#   (562245001, 33)],
#  842761003: [(842761001, 116),
#   (842761002, 112),
#   (598755001, 111),
#   (598755015, 85),
#   (598755002, 83),
#   (842761005, 60)],
#  608945020: [(608945001, 116),
#   (608945008, 98),
#   (608945019, 71),
#   (685816001, 38),
#   (685813001, 33),
#   (685816002, 32)],
#  569984020: [(569984001, 210),
#   (569984026, 145),
#   (569984019, 110),
#   (569984015, 99),
#   (569984002, 77),
#   (569984028, 57)],
#  608945002: [(608945001, 67),
#   (608945012, 44),
#   (733957001, 28),
#   (806388001, 26),
#   (685816001, 22),
#   (685816002, 22)],
#  854247001: [(854247002, 80),
#   (751471001, 74),
#   (762846001, 63),
#   (664074001, 61),
#   (841383002, 59),
#   (695632002, 55)],
#  790791004: [(695632001, 281),
#   (790791005, 187),
#   (751471001, 148),
#   (706016001, 124),
#   (640539001, 118),
#   (790791007, 117)],
#  857267001: [(706016001, 114),
#   (762846001, 111),
#   (762846008, 99),
#   (751471001, 82),
#   (695632002, 79),
#   (749699002, 78)],
#  857267002: [(841238002, 121),
#   (399256001, 61),
#   (399256005, 58),
#   (655784001, 45),
#   (857267001, 44),
#   (664074001, 43)],
#  817834005: [(706016001, 126),
#   (572797001, 80),
#   (751471001, 69),
#   (568601006, 68),
#   (568601007, 66),
#   (870293002, 64)],
#  822148001: [(822148003, 53),
#   (158340001, 45),
#   (822186001, 40),
#   (788846012, 38),
#   (673396002, 38),
#   (857277001, 36)],
#  668956002: [(668956001, 324),
#   (486639003, 148),
#   (307239005, 147),
#   (307239004, 144),
#   (706016001, 103),
#   (668956003, 93)],
#  668956001: [(668956002, 324),
#   (307239005, 319),
#   (486639003, 297),
#   (160442007, 199),
#   (706016001, 178),
#   (278811006, 178)],
#  808659001: [(610776001, 81),
#   (808659003, 67),
#   (610776002, 60),
#   (808659002, 60),
#   (160442007, 53),
#   (562245001, 48)],
#  810927003: [(810927001, 91),
#   (668956002, 47),
#   (486639003, 43),
#   (395575001, 42),
#   (492897001, 40),
#   (158340001, 38)],
#  486639011: [(561445005, 18),
#   (399223029, 17),
#   (153115040, 16),
#   (486639003, 16),
#   (610776002, 15),
#   (564448005, 15),
#   (661794002, 14)],
#  872172002: [(798407007, 24),
#   (720125001, 22),
#   (872172001, 20),
#   (803986007, 20),
#   (751471001, 19),
#   (610776002, 17)],
#  862054001: [(915292001, 37),
#   (811835009, 25),
#   (852174003, 20),
#   (706016001, 19),
#   (730683050, 18),
#   (924453003, 18)],
#  927529004: [(927529001, 21),
#   (790096001, 21),
#   (790096003, 17),
#   (759871002, 15),
#   (747373001, 15),
#   (448509014, 12)],
#  884319008: [(562245001, 122),
#   (706016001, 111),
#   (772005005, 100),
#   (610776002, 89),
#   (884319001, 89),
#   (751471001, 85)],
#  783346032: [(783346001, 351),
#   (783346018, 177),
#   (751471001, 163),
#   (783346016, 119),
#   (783346030, 115),
#   (783346028, 107)],
#  849886012: [(849886010, 106),
#   (809961007, 79),
#   (160442007, 55),
#   (849886002, 52),
#   (720125001, 49),
#   (708021001, 48)],
#  865929003: [(678342001, 581),
#   (706016001, 193),
#   (673677002, 153),
#   (568601006, 141),
#   (865929014, 139),
#   (561445005, 120)],
#  849886010: [(849886012, 106),
#   (160442007, 47),
#   (849886002, 45),
#   (706016002, 42),
#   (706016001, 40),
#   (372860002, 38)],
#  791142001: [(399136011, 79),
#   (658030029, 72),
#   (737224001, 60),
#   (774148001, 56),
#   (536139060, 56),
#   (827420001, 55)],
#  821759001: [(827420001, 101),
#   (158340001, 57),
#   (791131001, 55),
#   (772773002, 52),
#   (678942001, 52),
#   (562245001, 51)],
#  903926002: [(903926001, 149),
#   (706016001, 56),
#   (905945002, 54),
#   (914805002, 40),
#   (751471001, 39),
#   (158340001, 39)],
#  865929007: [(865929003, 88),
#   (865929014, 80),
#   (562245001, 42),
#   (706016001, 40),
#   (733098017, 37),
#   (733098008, 37)],
#  908292002: [(908292001, 26),
#   (706016001, 24),
#   (874754002, 19),
#   (751471001, 19),
#   (923534004, 18),
#   (706016002, 16)],
#  910601003: [(910601002, 279),
#   (910601001, 163),
#   (924243001, 113),
#   (706016001, 102),
#   (751471001, 94),
#   (478549001, 69)],
#  580600006: [(688018003, 9),
#   (612800010, 8),
#   (701229001, 8),
#   (700402002, 8),
#   (561548009, 8),
#   (556560005, 8)],
#  610776035: [(610776002, 519),
#   (610776010, 289),
#   (610776001, 270),
#   (610776020, 261),
#   (610776040, 231),
#   (610776023, 204)],
#  470985003: [(610776001, 709),
#   (706016001, 437),
#   (685816005, 324),
#   (562245001, 285),
#   (562245046, 209),
#   (610776002, 207)],
#  562245001: [(562245046, 7814),
#   (562245018, 5747),
#   (706016001, 5284),
#   (554450001, 3207),
#   (562245004, 2677),
#   (706016002, 2524)],
#  646592007: [(368979001, 42),
#   (573937001, 35),
#   (698387001, 29),
#   (779551002, 28),
#   (294008002, 26),
#   (779554002, 25)],
#  504155001: [(504155018, 336),
#   (504155011, 234),
#   (504155012, 223),
#   (706016001, 203),
#   (504155015, 177),
#   (507909001, 173)],
#  554477005: [(554477020, 1381),
#   (554477007, 1148),
#   (706016001, 732),
#   (490176001, 689),
#   (610776002, 626),
#   (562245001, 544)],
#  633130023: [(399256001, 58),
#   (572797001, 50),
#   (706016001, 50),
#   (562245001, 40),
#   (633130020, 36),
#   (651335008, 35)],
#  646592013: [(728152001, 70),
#   (368979001, 53),
#   (573937001, 28),
#   (646592007, 21),
#   (698387003, 21),
#   (554477027, 19)],
#  672625006: [(568601006, 128),
#   (573716012, 109),
#   (672625002, 101),
#   (562245001, 98),
#   (634249002, 97),
#   (610776001, 91)],
#  716956001: [(685694001, 213),
#   (689109001, 69),
#   (706016001, 67),
#   (692930001, 65),
#   (673396002, 65),
#   (448509014, 58)],
#  696638001: [(568597006, 41),
#   (715264001, 37),
#   (457892003, 35),
#   (717662001, 33),
#   (784427002, 31),
#   (562245001, 30)],
#  690683001: [(158340001, 49),
#   (753255006, 31),
#   (711440001, 21),
#   (712407001, 18),
#   (754751001, 18),
#   (561814002, 16)],
#  717518001: [(717518003, 107),
#   (685813001, 80),
#   (799190003, 74),
#   (706016001, 68),
#   (806388002, 58),
#   (806388001, 56)],
#  661306011: [(661306005, 228),
#   (661306008, 215),
#   (661306001, 156),
#   (706016001, 155),
#   (573716012, 129),
#   (610776001, 112)],
#  685766001: [(662418001, 132),
#   (706016001, 80),
#   (678942001, 70),
#   (706016002, 70),
#   (554772002, 62),
#   (611815001, 59)],
#  879294002: [(879294001, 326),
#   (879294004, 273),
#   (879294003, 166),
#   (610776002, 151),
#   (706016001, 122),
#   (610776001, 121)],
#  826620001: [(706016001, 135),
#   (887659002, 105),
#   (759871002, 85),
#   (706016002, 70),
#   (372860001, 69),
#   (372860002, 68)],
#  879294004: [(879294002, 273),
#   (879294001, 141),
#   (767799004, 134),
#   (767799003, 106),
#   (706016001, 106),
#   (610776002, 103)],
#  626405004: [(610776002, 28),
#   (706016001, 27),
#   (636323003, 25),
#   (399256001, 25),
#   (556255001, 23),
#   (446224002, 22)],
#  494691001: [(636323001, 366),
#   (399256005, 354),
#   (519583013, 317),
#   (636323002, 308),
#   (544116002, 293),
#   (399256013, 237)],
#  636323002: [(399256005, 1871),
#   (636323001, 1683),
#   (706016001, 1157),
#   (562245050, 960),
#   (706016002, 943),
#   (399223001, 769)],
#  626405005: [(664746001, 25),
#   (610776002, 23),
#   (179208001, 20),
#   (562245001, 19),
#   (458924002, 18),
#   (626405004, 16)],
#  562245039: [(562245001, 545),
#   (562245018, 494),
#   (706016002, 345),
#   (562245046, 344),
#   (706016001, 323),
#   (562245004, 310)],
#  554450004: [(554450001, 2689),
#   (706016002, 2195),
#   (554450036, 2126),
#   (554450027, 2088),
#   (706016001, 1702),
#   (554450019, 1565)],
#  682428001: [(706016001, 70),
#   (759871002, 63),
#   (228257001, 63),
#   (356289021, 62),
#   (729928001, 59),
#   (356289005, 55)],
#  661806001: [(661806003, 214),
#   (706016001, 100),
#   (615141002, 94),
#   (759871002, 88),
#   (675068002, 66),
#   (448509014, 66)],
#  661806003: [(661806001, 214),
#   (706016001, 102),
#   (711440001, 100),
#   (618800001, 97),
#   (699933001, 93),
#   (759871002, 89)],
#  649445001: [(706016001, 83),
#   (759871002, 58),
#   (706016002, 48),
#   (711714001, 46),
#   (610776002, 44),
#   (711053003, 40)],
#  705860001: [(711982002, 52),
#   (751471001, 51),
#   (507909001, 41),
#   (399256001, 35),
#   (573716012, 34),
#   (448509014, 29)],
#  507909004: [(507909001, 316),
#   (507909003, 229),
#   (507909024, 189),
#   (507909015, 109),
#   (507909022, 95),
#   (730946002, 89)],
#  695231001: [(706016001, 27),
#   (200182001, 25),
#   (554450001, 21),
#   (636323001, 18),
#   (610776001, 18),
#   (610776002, 18),
#   (579541001, 17)],
#  678291003: [(706016001, 81),
#   (678291002, 79),
#   (562245001, 63),
#   (678291006, 54),
#   (706016002, 49),
#   (537346013, 44)],
#  637667002: [(572998004, 210),
#   (637667001, 172),
#   (688873002, 106),
#   (706016001, 87),
#   (448509014, 87),
#   (572998002, 76)],
#  673638001: [(673638007, 965),
#   (706016001, 623),
#   (678942001, 562),
#   (673677002, 537),
#   (673638005, 522),
#   (610776002, 511)],
#  678291002: [(706016001, 121),
#   (678291003, 79),
#   (678291005, 79),
#   (706016002, 79),
#   (678291006, 77),
#   (562245001, 69)],
#  690621001: [(675070002, 111),
#   (562245001, 111),
#   (706016001, 110),
#   (610776002, 106),
#   (690621002, 94),
#   (487827024, 87)],
#  673638007: [(673638001, 965),
#   (706016001, 688),
#   (706016002, 477),
#   (610776001, 447),
#   (610776002, 436),
#   (706016003, 412)],
#  673638003: [(673638001, 455),
#   (673638007, 405),
#   (673638005, 295),
#   (465655010, 274),
#   (706016001, 213),
#   (678942001, 189)],
#  399136047: [(399136027, 499),
#   (399136004, 483),
#   (399136009, 481),
#   (399201022, 361),
#   (399136011, 361),
#   (399136061, 319)],
#  574112007: [(706016001, 57),
#   (759871002, 53),
#   (372860001, 47),
#   (372860002, 47),
#   (706016002, 37),
#   (111593001, 37)],
#  569562005: [(706016001, 323),
#   (372860001, 320),
#   (700851001, 264),
#   (464297007, 253),
#   (156231001, 217),
#   (611415001, 210)],
#  736593002: [(736592001, 2735),
#   (736593004, 706),
#   (736592003, 513),
#   (736593003, 500),
#   (736592002, 472),
#   (733935003, 228)],
#  568601026: [(568601006, 440),
#   (568601007, 275),
#   (568597025, 256),
#   (779781009, 159),
#   (573716012, 144),
#   (507909001, 142)],
#  569562001: [(569562005, 81),
#   (200182001, 65),
#   (542402001, 60),
#   (179208001, 47),
#   (156231001, 45),
#   (759871002, 45)],
#  569562014: [(700851001, 61),
#   (706016001, 52),
#   (706016002, 41),
#   (160442007, 39),
#   (688537004, 38),
#   (156231001, 35)],
#  569562012: [(569562005, 86),
#   (706016001, 56),
#   (706016002, 49),
#   (700851002, 46),
#   (372860001, 44),
#   (507909001, 41)],
#  618800007: [(618800001, 1205),
#   (706016001, 377),
#   (671852004, 326),
#   (749699002, 307),
#   (448509014, 290),
#   (469137001, 276)],
#  736592001: [(736593002, 2735),
#   (736592003, 574),
#   (736593004, 508),
#   (736592002, 460),
#   (736593003, 397),
#   (689109003, 260)],
#  618800001: [(706016001, 1590),
#   (618800007, 1205),
#   (706016002, 915),
#   (671852003, 894),
#   (448509014, 855),
#   (469137001, 839)],
#  777815001: [(629420001, 206),
#   (678342028, 45),
#   (706016001, 37),
#   (448509014, 36),
#   (673396002, 31),
#   (717490002, 27),
#   (111593001, 25)],
#  763077002: [(763077001, 194),
#   (706016001, 160),
#   (562245001, 119),
#   (573716012, 113),
#   (562245050, 102),
#   (783346001, 97)],
#  763077001: [(706016001, 217),
#   (763077002, 194),
#   (695632002, 189),
#   (448509014, 175),
#   (562245001, 157),
#   (720125001, 141)],
#  779883001: [(706016001, 117),
#   (562245001, 75),
#   (448509014, 74),
#   (673396002, 68),
#   (741356002, 67),
#   (706016002, 66)],
#  697054010: [(697054027, 201),
#   (706016001, 149),
#   (697054026, 146),
#   (610776002, 139),
#   (562245001, 136),
#   (697054014, 136)],
#  770658001: [(735496001, 342),
#   (735539002, 53),
#   (156231001, 53),
#   (735532001, 48),
#   (735537001, 40),
#   (448509014, 37)],
#  740450007: [(507909001, 113),
#   (507909024, 102),
#   (507909026, 57),
#   (156231001, 47),
#   (706016001, 42),
#   (372860001, 41)],
#  357792011: [(448509014, 121),
#   (706016001, 106),
#   (759871002, 104),
#   (351484002, 88),
#   (111593001, 86),
#   (610776001, 86)],
#  733935003: [(733936003, 2069),
#   (733935001, 738),
#   (733936001, 654),
#   (739590002, 629),
#   (688537004, 534),
#   (748236001, 513)],
#  270382004: [(706016001, 84),
#   (372860001, 79),
#   (673396002, 65),
#   (372860002, 59),
#   (399223001, 58),
#   (706016002, 48)],
#  717943001: [(706016001, 76),
#   (717943002, 55),
#   (562245046, 55),
#   (706016003, 52),
#   (741356002, 45),
#   (734460001, 44)],
#  357792003: [(357792011, 33),
#   (706016001, 32),
#   (448509014, 30),
#   (372860002, 25),
#   (228257001, 25),
#   (706016002, 24)],
#  370594006: [(706016001, 48),
#   (351484002, 36),
#   (610776002, 36),
#   (759871002, 34),
#   (706016002, 33),
#   (564786001, 32)],
#  590928019: [(712924008, 5165),
#   (590928001, 827),
#   (688537004, 667),
#   (684209014, 564),
#   (688537012, 532),
#   (351484002, 487)],
#  736341002: [(687034007, 974),
#   (736593002, 167),
#   (689109003, 156),
#   (615986003, 155),
#   (448509014, 143),
#   (736592001, 134)],
#  716672001: [(716672003, 2564),
#   (749699002, 1554),
#   (749699001, 1254),
#   (706016001, 1117),
#   (610776001, 869),
#   (610776002, 781)],
#  765773007: [(765773003, 800),
#   (749699002, 478),
#   (765773004, 397),
#   (716672001, 370),
#   (706016001, 357),
#   (749699001, 286)],
#  758642001: [(706016001, 167),
#   (715538001, 138),
#   (562245001, 134),
#   (754910001, 132),
#   (752477003, 132),
#   (762846001, 131)],
#  734623002: [(734623003, 295),
#   (706016001, 145),
#   (759871002, 142),
#   (689109001, 136),
#   (692930001, 101),
#   (156231001, 98)],
#  789331001: [(789331003, 283),
#   (448509014, 94),
#   (735625002, 86),
#   (618800007, 81),
#   (689109001, 81),
#   (706016001, 79)],
#  716581003: [(716581001, 533),
#   (716581002, 433),
#   (706016001, 410),
#   (706016002, 295),
#   (610776002, 269),
#   (562245001, 235)],
#  758002003: [(757995003, 680),
#   (758002004, 123),
#   (757995004, 96),
#   (448509014, 92),
#   (758064001, 81),
#   (759871002, 81)],
#  757995004: [(758002004, 665),
#   (759871002, 132),
#   (783380003, 101),
#   (448509014, 100),
#   (757995003, 99),
#   (689109001, 98)],
#  757995003: [(758002003, 680),
#   (757995004, 99),
#   (733935001, 95),
#   (448509014, 84),
#   (758064001, 82),
#   (758002004, 79)],
#  758002004: [(757995004, 665),
#   (698283005, 155),
#   (759871002, 143),
#   (688537004, 132),
#   (758002003, 123),
#   (706016001, 110)],
#  758060001: [(758064001, 7149),
#   (758050001, 2244),
#   (758089002, 2187),
#   (758049001, 2123),
#   (758043001, 2046),
#   (758118001, 1959)],
#  758064001: [(758060001, 7149),
#   (758050001, 2274),
#   (758049001, 2232),
#   (758118001, 2084),
#   (758089002, 2066),
#   (758088002, 1885)],
#  736530010: [(736531008, 679),
#   (783440004, 320),
#   (736530007, 291),
#   (720137007, 255),
#   (736530011, 198),
#   (736531006, 191)],
#  736593003: [(736592002, 2603),
#   (736593004, 807),
#   (736593002, 500),
#   (736592003, 418),
#   (736592001, 397),
#   (688537012, 336)],
#  714495002: [(429313025, 111),
#   (529012040, 107),
#   (706016001, 104),
#   (700329001, 101),
#   (679284001, 68),
#   (706016002, 65)],
#  758118001: [(758064001, 2084),
#   (758060001, 1959),
#   (758050001, 1361),
#   (758089002, 1328),
#   (758049001, 1322),
#   (758088002, 1197)],
#  790167001: [(678342001, 572),
#   (790167002, 199),
#   (158340001, 107),
#   (790167004, 101),
#   (561445005, 101),
#   (706016001, 88)],
#  798381003: [(688558002, 176),
#   (464297007, 98),
#   (798381004, 93),
#   (706016001, 81),
#   (656367001, 73),
#   (448509014, 68)],
#  798381004: [(111586001, 123),
#   (798381003, 93),
#   (695632002, 68),
#   (706016001, 66),
#   (716672001, 57),
#   (688537010, 53)],
#  612481002: [(612481001, 1713),
#   (612481004, 1510),
#   (741356002, 1313),
#   (706016001, 1148),
#   (706016002, 1027),
#   (759871002, 837)],
#  612481004: [(612481002, 1510),
#   (612481001, 737),
#   (706016001, 618),
#   (741356002, 615),
#   (706016002, 445),
#   (759871002, 332)],
#  716581002: [(716581001, 644),
#   (716581003, 433),
#   (610776002, 318),
#   (610776001, 294),
#   (706016001, 289),
#   (697060013, 274)],
#  560221006: [(600380003, 504),
#   (559616001, 362),
#   (351484002, 264),
#   (688537004, 211),
#   (706016001, 204),
#   (688537011, 202)],
#  696931002: [(696931001, 72),
#   (706016001, 59),
#   (519583013, 45),
#   (706016002, 45),
#   (706016003, 31),
#   (805323002, 30)],
#  788632004: [(706016001, 245),
#   (706016002, 181),
#   (788632006, 143),
#   (759871002, 129),
#   (610776001, 122),
#   (448509014, 111)],
#  772014001: [(772014002, 100),
#   (706016001, 73),
#   (759871002, 64),
#   (749699013, 51),
#   (706016002, 45),
#   (706016003, 38)],
#  745232001: [(706016001, 828),
#   (688105002, 431),
#   (706016002, 386),
#   (745232002, 381),
#   (759871002, 345),
#   (399223001, 325)],
#  746775008: [(746775001, 488),
#   (737222009, 324),
#   (736531006, 275),
#   (783440005, 269),
#   (746775002, 261),
#   (611415005, 256)],
#  772902001: [(706016001, 1781),
#   (759871002, 1233),
#   (706016002, 1120),
#   (772902002, 975),
#   (772902003, 965),
#   (448509014, 782)],
#  746775004: [(737222004, 800),
#   (746775001, 632),
#   (746775002, 375),
#   (746775003, 370),
#   (761621001, 298),
#   (746775008, 228)],
#  707269001: [(707269003, 961),
#   (706016001, 309),
#   (707269007, 308),
#   (429313006, 303),
#   (707269004, 289),
#   (834906001, 281)],
#  456163060: [(685814001, 918),
#   (706016001, 632),
#   (803757001, 409),
#   (610776002, 396),
#   (372860001, 369),
#   (673677002, 319)],
#  736531006: [(736530007, 4133),
#   (736531001, 1130),
#   (464297007, 806),
#   (611415005, 690),
#   (611415001, 681),
#   (706016001, 634)],
#  799409003: [(799410003, 2923),
#   (799409001, 259),
#   (811925009, 211),
#   (802980002, 211),
#   (607030008, 210),
#   (706016001, 208)],
#  803757012: [(803757001, 874),
#   (803757004, 604),
#   (803757013, 342),
#   (706016001, 313),
#   (803757014, 292),
#   (610776002, 262)],
#  799410003: [(799409003, 2923),
#   (799410001, 217),
#   (799409001, 212),
#   (599580038, 193),
#   (706016001, 190),
#   (811925009, 175)],
#  383152003: [(383152002, 733),
#   (707269001, 209),
#   (429313006, 195),
#   (578374001, 174),
#   (707269003, 165),
#   (679284001, 143)],
#  812363002: [(812364001, 814),
#   (812363008, 268),
#   (812364010, 199),
#   (689109001, 178),
#   (811887001, 167),
#   (759871002, 163)],
#  805000003: [(739348006, 331),
#   (805000001, 326),
#   (739348005, 318),
#   (791587001, 160),
#   (720125001, 138),
#   (655347002, 127)],
#  611415005: [(611415001, 2216),
#   (429313006, 1527),
#   (736530007, 1197),
#   (464297007, 955),
#   (706016001, 858),
#   (529008026, 737)],
#  799409001: [(799410001, 750),
#   (799409003, 259),
#   (799410003, 212),
#   (607030008, 119),
#   (607031009, 91),
#   (699423001, 75)],
#  866383001: [(739590027, 2864),
#   (590928001, 1569),
#   (799421001, 1089),
#   (811887001, 1018),
#   (688537004, 898),
#   (599580017, 889)],
#  772773001: [(772773002, 2626),
#   (554772002, 1541),
#   (772773004, 1149),
#   (778064001, 889),
#   (718278001, 817),
#   (610776002, 785)],
#  772014002: [(759871002, 108),
#   (706016001, 104),
#   (772014001, 100),
#   (610776002, 91),
#   (706016002, 85),
#   (618800001, 58)],
#  834906001: [(707269001, 281),
#   (834906002, 234),
#   (855080002, 202),
#   (827907002, 123),
#   (372860001, 116),
#   (834906003, 112)],
#  557599022: [(611415001, 865),
#   (464297007, 780),
#   (470789001, 595),
#   (706016001, 567),
#   (557599001, 540),
#   (557599023, 528)],
#  803985004: [(803986005, 240),
#   (570004009, 173),
#   (803985001, 164),
#   (816612006, 132),
#   (798407002, 130),
#   (736530007, 122)],
#  740922001: [(720125001, 612),
#   (372860001, 538),
#   (464297007, 324),
#   (720125007, 318),
#   (372860002, 316),
#   (730683001, 288)],
#  814641002: [(814641001, 122),
#   (814641006, 82),
#   (610776002, 71),
#   (610776001, 71),
#   (554598003, 67),
#   (706016001, 61)],
#  707269004: [(707269003, 578),
#   (707269001, 289),
#   (707269007, 188),
#   (707269005, 135),
#   (372860001, 90),
#   (834906002, 87)],
#  708311026: [(849361003, 174),
#   (751471001, 57),
#   (673677002, 48),
#   (708311016, 45),
#   (751471021, 41),
#   (678942001, 41)],
#  809961001: [(809961002, 298),
#   (827935002, 195),
#   (791587009, 143),
#   (720125001, 137),
#   (810838011, 125),
#   (849886001, 116)],
#  795975009: [(795975003, 204),
#   (795975004, 172),
#   (706016001, 89),
#   (828295001, 82),
#   (572797044, 69),
#   (795975011, 61)],
#  786187001: [(786187002, 479),
#   (786187003, 377),
#   (855080001, 341),
#   (706016001, 253),
#   (579302001, 245),
#   (707269001, 202)],
#  715624001: [(706016001, 1300),
#   (706016002, 869),
#   (759871002, 867),
#   (806388001, 828),
#   (715624010, 663),
#   (610776002, 662)],
#  827935002: [(809961001, 195),
#   (854043006, 78),
#   (759871002, 77),
#   (849942001, 68),
#   (810838011, 65),
#   (809961002, 55)],
#  772773002: [(772773001, 2626),
#   (778064003, 1583),
#   (772773004, 977),
#   (554772003, 942),
#   (731608002, 589),
#   (610776001, 559)],
#  797568001: [(611415001, 65),
#   (803986001, 53),
#   (557599022, 48),
#   (783440002, 45),
#   (826955001, 43),
#   (797529001, 39)],
#  797567002: [(797565002, 368),
#   (797567001, 178),
#   (736531006, 144),
#   (736530007, 104),
#   (611415001, 95),
#   (736531001, 90)],
#  798407008: [(810557002, 498),
#   (798407001, 392),
#   (798407010, 373),
#   (572998004, 241),
#   (819113003, 216),
#   (810557006, 193)],
#  620573008: [(464297007, 561),
#   (704756001, 374),
#   (706016001, 248),
#   (372860001, 169),
#   (706016002, 160),
#   (611415001, 148)],
#  776237011: [(599580038, 6834),
#   (776237020, 957),
#   (776237006, 929),
#   (571706010, 862),
#   (599580052, 777),
#   (599580055, 712)],
#  894139007: [(894140006, 331),
#   (832331001, 130),
#   (894139004, 95),
#   (448509014, 63),
#   (894140004, 56),
#   (869691002, 56)],
#  866383008: [(919248002, 960),
#   (866383006, 546),
#   (866383001, 316),
#   (599580012, 291),
#   (811925001, 174),
#   (706016001, 169)],
#  811925001: [(811927001, 1863),
#   (811925009, 730),
#   (811927007, 382),
#   (866383001, 358),
#   (741356002, 278),
#   (811925002, 255)],
#  877278002: [(678342001, 595),
#   (610776002, 368),
#   (706016001, 356),
#   (706016002, 270),
#   (610776001, 266),
#   (749699002, 253)],
#  774785002: [(678342001, 574),
#   (561445005, 86),
#   (706016002, 83),
#   (850897001, 83),
#   (599580055, 82),
#   (706016001, 81)],
#  835008005: [(706016001, 426),
#   (610776001, 294),
#   (448509014, 281),
#   (751471001, 275),
#   (716672001, 268),
#   (610776002, 266)],
#  696796003: [(629758013, 192),
#   (660994002, 42),
#   (741220017, 33),
#   (560783011, 32),
#   (663285001, 32),
#   (111593001, 29)],
#  701208001: [(720329001, 144),
#   (701208002, 139),
#   (706016001, 113),
#   (484398001, 108),
#   (778064001, 100),
#   (720125001, 98)],
#  278811006: [(706016001, 629),
#   (278811007, 610),
#   (372860001, 499),
#   (160442007, 488),
#   (158340001, 470),
#   (492897001, 461)],
#  733067001: [(473954008, 903),
#   (733067002, 538),
#   (470789001, 317),
#   (160442010, 251),
#   (372860001, 249),
#   (307239005, 243)],
#  536139006: [(610776002, 1674),
#   (706016001, 1648),
#   (536139010, 1346),
#   (372860001, 1146),
#   (562245046, 868),
#   (706016002, 850)],
#  668956003: [(668956001, 118),
#   (728162001, 104),
#   (307239005, 97),
#   (668956002, 93),
#   (189634001, 81),
#   (486639003, 78)],
#  820508001: [(820508002, 219),
#   (610776002, 198),
#   (706016001, 187),
#   (892051001, 178),
#   (877278002, 169),
#   (796210001, 166)],
#  473954015: [(473954008, 206),
#   (473954014, 140),
#   (700701005, 114),
#   (733067001, 99),
#   (470789031, 91),
#   (153115043, 85)],
#  783346001: [(751471001, 3922),
#   (783346018, 3199),
#   (573716012, 2643),
#   (706016001, 1689),
#   (783346016, 1519),
#   (796210001, 1375)],
#  905518001: [(730683050, 270),
#   (905518002, 263),
#   (720125001, 261),
#   (610776002, 253),
#   (912204001, 210),
#   (804992034, 207)],
#  852584006: [(730683050, 88),
#   (912204001, 73),
#   (852584001, 71),
#   (804992017, 68),
#   (720125001, 62),
#   (730683019, 58)],
#  757904007: [(706016001, 101),
#   (372860001, 53),
#   (372860002, 49),
#   (399223001, 48),
#   (160442007, 48),
#   (673396002, 46)],
#  912204009: [(912204001, 48),
#   (912204008, 42),
#   (852584006, 26),
#   (464297007, 22),
#   (730683036, 21),
#   (809961002, 18),
#   (372860001, 17)],
#  501915004: [(501924004, 46),
#   (501926003, 41),
#   (501915005, 37),
#   (684992001, 36),
#   (501926005, 35),
#   (501924003, 30)],
#  355569002: [(355569001, 3352),
#   (717464001, 948),
#   (717464002, 684),
#   (355072002, 404),
#   (706016001, 327),
#   (711053003, 258)],
#  355569001: [(717464001, 5273),
#   (355569002, 3352),
#   (717464002, 968),
#   (108775015, 801),
#   (355072001, 734),
#   (610776002, 671)],
#  532578030: [(532578010, 77),
#   (532578029, 57),
#   (706016001, 57),
#   (610776002, 57),
#   (610776001, 43),
#   (706016002, 42)],
#  689389004: [(706016001, 404),
#   (695632002, 307),
#   (675068002, 271),
#   (507910001, 253),
#   (610776002, 250),
#   (697054003, 239)],
#  591334019: [(591334003, 1774),
#   (636587001, 1408),
#   (593829002, 1050),
#   (678942001, 884),
#   (591334035, 837),
#   (591334039, 731)],
#  796210008: [(796210001, 864),
#   (562245001, 465),
#   (706016001, 436),
#   (573716012, 395),
#   (562245046, 385),
#   (783346001, 357)],
#  768465006: [(768465005, 418),
#   (768465002, 368),
#   (768465003, 223),
#   (751471001, 205),
#   (706016001, 181),
#   (673677002, 181)],
#  761406003: [(706016001, 196),
#   (761406001, 144),
#   (759871002, 123),
#   (706016002, 92),
#   (156231001, 88),
#   (399223001, 74)],
#  872000002: [(872000003, 219),
#   (706016001, 162),
#   (872000001, 157),
#   (749699002, 144),
#   (749699001, 129),
#   (872000005, 126)],
#  854687004: [(488561032, 98),
#   (610776001, 90),
#   (706016001, 77),
#   (228257001, 75),
#   (156231001, 72),
#   (854687009, 65)],
#  835657001: [(706016001, 64),
#   (741356002, 56),
#   (720125001, 42),
#   (830936003, 40),
#   (706016002, 37),
#   (448509001, 35)],
#  874546001: [(706016001, 117),
#   (759871002, 103),
#   (842062003, 79),
#   (562245046, 77),
#   (448509014, 77),
#   (874546003, 75)],
#  821163010: [(821163008, 213),
#   (821163003, 212),
#   (821163009, 127),
#   (892051002, 111),
#   (749699001, 106),
#   (610776002, 100)],
#  573716012: [(573716050, 2934),
#   (783346001, 2643),
#   (573716049, 2088),
#   (751471001, 2055),
#   (562245001, 1915),
#   (706016001, 1767)],
#  835348001: [(835348006, 179),
#   (706016001, 173),
#   (751471001, 169),
#   (835348008, 156),
#   (673396002, 143),
#   (448509014, 126)],
#  816832010: [(816832001, 128),
#   (762846001, 50),
#   (836142004, 38),
#   (697060013, 33),
#   (788176001, 32),
#   (568601006, 29)],
#  908663001: [(534164001, 16),
#   (793184001, 10),
#   (663010006, 9),
#   (433414040, 8),
#   (754792001, 8),
#   (852488001, 8),
#   (879916001, 8)],
#  865137003: [(865137001, 35),
#   (534164001, 32),
#   (882261002, 18),
#   (534164030, 17),
#   (663010006, 16),
#   (433414039, 15)],
#  865137001: [(534164001, 38),
#   (865137003, 35),
#   (663010006, 24),
#   (534164030, 23),
#   (215589001, 22),
#   (882261003, 20)],
#  892562001: [(865926002, 34),
#   (933706001, 20),
#   (762762001, 18),
#   (534164001, 13),
#   (663010006, 12),
#   (554450027, 12),
#   (834063001, 12)],
#  663010006: [(534164001, 70),
#   (433414038, 42),
#   (596877005, 32),
#   (433414039, 30),
#   (215589001, 28),
#   (510465001, 27)],
#  882261002: [(534164001, 49),
#   (772747005, 36),
#   (868320001, 28),
#   (882261003, 23),
#   (717683009, 23),
#   (663010006, 22)],
#  707373005: [(534164001, 15),
#   (663010006, 14),
#   (433414039, 12),
#   (687635004, 10),
#   (534164028, 9),
#   (215589001, 9)],
#  433414039: [(534164001, 60),
#   (534164029, 35),
#   (663010006, 30),
#   (534164028, 29),
#   (215589001, 26),
#   (534164030, 26)],
#  433414040: [(534164001, 35),
#   (663010006, 19),
#   (534164032, 19),
#   (882261002, 15),
#   (865137001, 12),
#   (215589001, 12),
#   (433414038, 12)],
#  671553001: [(671553002, 227),
#   (706016002, 97),
#   (732017001, 94),
#   (579541001, 90),
#   (678942001, 89),
#   (579541031, 80)],
#  673638005: [(673638001, 522),
#   (673638007, 320),
#   (673638003, 295),
#   (678942001, 217),
#   (591334019, 209),
#   (673638002, 195)],
#  579541027: [(579541011, 88),
#   (579541001, 88),
#   (579541030, 68),
#   (579541004, 61),
#   (579541026, 50),
#   (787481002, 47)],
#  504155011: [(504155018, 323),
#   (504155001, 234),
#   (706016001, 177),
#   (504155015, 158),
#   (706016002, 144),
#   (572797001, 138)],
#  721365001: [(740895001, 172),
#   (706016001, 101),
#   (759871002, 99),
#   (372860001, 67),
#   (399223001, 63),
#   (706016002, 61)],
#  721320007: [(721320014, 589),
#   (721320010, 478),
#   (721320013, 444),
#   (721320006, 442),
#   (721320001, 328),
#   (721320012, 280)],
#  690617006: [(690617002, 56),
#   (572797001, 49),
#   (768912001, 42),
#   (568597006, 34),
#   (690617001, 32),
#   (525821001, 31)],
#  615141002: [(706016001, 1190),
#   (615141001, 1062),
#   (706016002, 776),
#   (464297007, 557),
#   (759871002, 536),
#   (706016003, 531)],
#  783346024: [(783346020, 660),
#   (783346018, 621),
#   (783346001, 530),
#   (783346016, 400),
#   (783346017, 311),
#   (751471001, 252)],
#  614854005: [(706016001, 776),
#   (464297007, 741),
#   (758034001, 654),
#   (372860001, 562),
#   (706016002, 476),
#   (603145001, 472)],
#  733097001: [(733097008, 1528),
#   (733097004, 760),
#   (706016001, 585),
#   (706016002, 404),
#   (759871002, 354),
#   (372860001, 347)],
#  654046001: [(464297007, 212),
#   (706016001, 211),
#   (612358004, 204),
#   (611415001, 203),
#   (579302001, 194),
#   (703474001, 191)],
#  867357003: [(867357001, 312),
#   (640021005, 136),
#   (888727010, 113),
#   (871957003, 109),
#   (857812004, 72),
#   (706016001, 71)],
#  805406002: [(819866002, 130),
#   (805406004, 107),
#   (760123005, 74),
#   (156231001, 72),
#   (799349001, 71),
#   (673677002, 71)],
#  859424001: [(859424004, 241),
#   (853839001, 152),
#   (859399006, 142),
#   (610776002, 121),
#   (706016001, 118),
#   (880186003, 117)],
#  826252001: [(706016001, 433),
#   (826252003, 369),
#   (706016002, 237),
#   (706016003, 220),
#   (562245001, 215),
#   (695632002, 215)],
#  679284001: [(429313006, 495),
#   (706016001, 462),
#   (706016002, 311),
#   (858147001, 279),
#   (372860001, 273),
#   (611415001, 263)],
#  861024001: [(448509014, 76),
#   (529953007, 61),
#   (689109001, 59),
#   (751471001, 59),
#   (759871002, 53),
#   (695632002, 51)],
#  779871005: [(779871001, 88),
#   (759871002, 76),
#   (706016001, 74),
#   (484398001, 67),
#   (448509014, 67),
#   (870970001, 66)],
#  858161001: [(858161002, 261),
#   (706016001, 132),
#   (759871002, 110),
#   (484398001, 104),
#   (448509014, 90),
#   (892308001, 84)],
#  552716001: [(706016001, 445),
#   (706016002, 323),
#   (673396002, 244),
#   (372860001, 233),
#   (759871002, 218),
#   (706016003, 177)],
#  794819001: [(794819002, 633),
#   (678942001, 406),
#   (673677002, 371),
#   (610776002, 308),
#   (794819003, 307),
#   (579541001, 290)],
#  604837006: [(156231001, 124),
#   (689109001, 80),
#   (689109003, 73),
#   (759871002, 70),
#   (692930001, 66),
#   (448509014, 63)],
#  211143037: [(160442007, 63),
#   (448509014, 47),
#   (610776001, 45),
#   (590928001, 37),
#   (351484002, 37),
#   (706016001, 36)],
#  695263001: [(695263003, 162),
#   (712216001, 141),
#   (706016002, 77),
#   (610776002, 75),
#   (665098001, 75),
#   (706016001, 73)],
#  636938005: [(636938001, 300),
#   (111593001, 112),
#   (636938003, 105),
#   (706016001, 104),
#   (846407001, 97),
#   (160442007, 89)],
#  568570002: [(692930001, 188),
#   (689109001, 81),
#   (539723001, 75),
#   (539723005, 70),
#   (568571002, 54),
#   (689109003, 50)],
#  568570001: [(568571001, 235),
#   (568570002, 43),
#   (568572001, 42),
#   (689109001, 34),
#   (689109003, 31),
#   (692930003, 29)],
#  568571001: [(568570001, 235),
#   (689109003, 40),
#   (568570002, 36),
#   (568571002, 36),
#   (714790020, 36),
#   (668537001, 32)],
#  610059001: [(609719001, 36),
#   (559630002, 27),
#   (566140001, 23),
#   (569046001, 19),
#   (399223001, 17),
#   (559616001, 17)],
#  625939003: [(625939002, 1149),
#   (610776001, 728),
#   (610776002, 523),
#   (355072002, 437),
#   (711053004, 413),
#   (630319001, 403)],
#  684890001: [(706016001, 283),
#   (610776002, 176),
#   (663679001, 153),
#   (156231001, 148),
#   (448509014, 145),
#   (706016002, 129)],
#  625939035: [(678694003, 135),
#   (625939014, 106),
#   (610776002, 105),
#   (706016001, 84),
#   (706016002, 54),
#   (625939002, 53)],
#  705973002: [(629746002, 15),
#   (711053007, 14),
#   (629758005, 14),
#   (799365002, 13),
#   (711440001, 13),
#   (786304002, 13)],
#  469137012: [(469137001, 121),
#   (706016001, 107),
#   (759871002, 66),
#   (706016002, 63),
#   (469137011, 63),
#   (448509014, 62)],
#  634332001: [(706016001, 163),
#   (111593001, 158),
#   (634426008, 137),
#   (610776001, 123),
#   (634332004, 121),
#   (399223001, 117)],
#  651336004: [(712517005, 57),
#   (807064002, 51),
#   (651336001, 37),
#   (706016001, 37),
#   (355072002, 31),
#   (772005009, 29)],
#  497513001: [(507909003, 65),
#   (156231001, 64),
#   (759871002, 41),
#   (372860001, 41),
#   (673677002, 40),
#   (111593001, 40),
#   (464297007, 38)],
#  648449002: [(648449001, 91),
#   (156231001, 27),
#   (706016001, 25),
#   (539197011, 24),
#   (372860001, 21),
#   (685814001, 20)],
#  710708004: [(661306008, 192),
#   (766346001, 178),
#   (610776002, 141),
#   (710708002, 139),
#   (710708005, 136),
#   (710708001, 123)],
#  723620001: [(723620003, 78),
#   (749968001, 66),
#   (156231001, 63),
#   (594978030, 61),
#   (594978031, 61),
#   (361531002, 60)],
#  718623001: [(742769001, 177),
#   (706016001, 131),
#   (718623005, 122),
#   (706016003, 105),
#   (448509014, 94),
#   (706016002, 87)],
#  700371004: [(700370004, 240),
#   (529008045, 181),
#   (464297007, 142),
#   (720137005, 116),
#   (372860001, 115),
#   (701244004, 111),
#   (720137001, 110)],
#  156231001: [(228257001, 4492),
#   (372860001, 2646),
#   (111586001, 2186),
#   (464297007, 2143),
#   (200182001, 1995),
#   (156231002, 1985)],
#  720137004: [(720137001, 1679),
#   (720137003, 1092),
#   (720137002, 1033),
#   (720137007, 1000),
#   (720137005, 942),
#   (704720010, 462)],
#  733045007: [(729318008, 294),
#   (754877003, 241),
#   (733045002, 105),
#   (372860001, 93),
#   (611415005, 91),
#   (464297007, 87)],
#  720137003: [(720137001, 2485),
#   (720137002, 1678),
#   (720137004, 1092),
#   (720137005, 987),
#   (720137007, 900),
#   (704720005, 407)],
#  751530004: [(751530001, 621),
#   (751530003, 449),
#   (751530002, 287),
#   (706016001, 192),
#   (759871002, 160),
#   (610776001, 147)],
#  729318008: [(733045007, 294),
#   (729322004, 207),
#   (736530007, 123),
#   (729318007, 106),
#   (706016001, 102),
#   (729318004, 99)],
#  729322004: [(729318008, 207),
#   (754877003, 138),
#   (729322002, 97),
#   (733045007, 78),
#   (733044003, 60),
#   (610776002, 59)],
#  590928001: [(688537004, 6515),
#   (712924012, 3787),
#   (599580017, 3762),
#   (684209004, 2257),
#   (351484002, 2197),
#   (706016001, 1889)],
#  767436002: [(767438002, 1919),
#   (767436003, 346),
# ...
#   (767869001, 1073),
#   (108775044, 880),
#   (372860001, 876),
#   (706016001, 865)],
#  633929002: [(372860001, 26),
#   (706016001, 26),
#   (156231001, 25),
#   (539723005, 20),
#   (484398001, 19),
#   (372860002, 19)],
#  665851001: [(372860001, 123),
#   (711053003, 118),
#   (189616006, 118),
#   (477107015, 100),
#   (189616001, 85),
#   (746168003, 80)],
#  502522001: [(179123001, 360),
#   (458239001, 356),
#   (731146001, 351),
#   (637255001, 319),
#   (189634001, 278),
#   (706016001, 226)],
#  639678002: [(610776002, 83),
#   (562245001, 64),
#   (573716012, 58),
#   (706016001, 56),
#   (156231001, 52),
#   (399256001, 51)],
#  504154033: [(504154034, 518),
#   (504154037, 442),
#   (562245001, 334),
#   (706016001, 334),
#   (610776002, 317),
#   (504154027, 271)],
#  538699007: [(538699001, 2341),
#   (108775044, 657),
#   (108775015, 546),
#   (767869001, 505),
#   (767869002, 490),
#   (372860001, 455)],
#  714826002: [(706016001, 297),
#   (706016002, 162),
#   (714826005, 145),
#   (610776002, 141),
#   (759871002, 139),
#   (706016003, 119)],
#  682550020: [(189616006, 342),
#   (728162001, 218),
#   (678086001, 204),
#   (706016001, 186),
#   (189634001, 183),
#   (610776002, 140)],
#  679709014: [(372860002, 11),
#   (620425001, 11),
#   (717773001, 11),
#   (673552003, 10),
#   (776237020, 10),
#   (608776002, 9)],
#  696678004: [(583534014, 346),
#   (696678006, 149),
#   (583534013, 149),
#   (696678005, 111),
#   (696678007, 97),
#   (678942001, 83)],
#  697031002: [(697031001, 342),
#   (787946002, 218),
#   (706016001, 190),
#   (351484002, 174),
#   (562245001, 168),
#   (751471001, 156)],
#  718438002: [(697054015, 47),
#   (158340001, 40),
#   (706016001, 37),
#   (156231001, 33),
#   (724180002, 31),
#   (399256001, 30)],
#  685470002: [(706016001, 91),
#   (464297007, 73),
#   (706016002, 66),
#   (372860001, 63),
#   (759871002, 56),
#   (399223001, 48)],
#  719021002: [(399223029, 19),
#   (160442010, 18),
#   (399223001, 17),
#   (759871002, 16),
#   (728162002, 16),
#   (678942001, 16),
#   (636323001, 15)],
#  707611002: [(399223001, 105),
#   (706016001, 99),
#   (706016002, 96),
#   (372860001, 81),
#   (156231001, 75),
#   (372860002, 67),
#   (610776002, 66)],
#  718968002: [(706016001, 64),
#   (464297007, 58),
#   (156231001, 52),
#   (759871002, 52),
#   (399223001, 52),
#   (629758013, 51)],
#  372860001: [(372860002, 10113),
#   (608776002, 3594),
#   (706016001, 3557),
#   (464297007, 3200),
#   (156231001, 2646),
#   (610776002, 2276)],
#  708471003: [(708471001, 493),
#   (610776002, 210),
#   (708471005, 210),
#   (708471006, 183),
#   (562245001, 154),
#   (708428003, 152)],
#  664319005: [(664319001, 751),
#   (664319021, 457),
#   (706016001, 336),
#   (610776002, 287),
#   (664319015, 261),
#   (706016002, 252)],
#  724905009: [(724905008, 490),
#   (724905016, 299),
#   (724905001, 241),
#   (714790008, 230),
#   (610776002, 211),
#   (837939001, 198)],
#  724905008: [(724905009, 490),
#   (400285006, 272),
#   (610776002, 191),
#   (724905016, 153),
#   (666254001, 141),
#   (751471001, 138)],
#  792604001: [(792604002, 247),
#   (610776002, 156),
#   (706016001, 147),
#   (610776001, 120),
#   (554598001, 86),
#   (372860001, 83)],
#  664074039: [(664074001, 408),
#   (610776002, 158),
#   (664074007, 149),
#   (664074059, 135),
#   (678942001, 128),
#   (664074030, 124)],
#  770315005: [(770315006, 1027),
#   (770315007, 551),
#   (664074001, 539),
#   (751471001, 522),
#   (678942001, 482),
#   (610776002, 481)],
#  770315007: [(770315005, 551),
#   (770315006, 332),
#   (770315001, 244),
#   (678942001, 202),
#   (706016001, 202),
#   (562245046, 183)],
#  733099001: [(733099003, 328),
#   (610776002, 235),
#   (733099002, 219),
#   (664074001, 175),
#   (706016001, 170),
#   (610776001, 157)],
#  788176001: [(745475001, 195),
#   (788176003, 195),
#   (788176005, 171),
#   (610776002, 160),
#   (817491001, 153),
#   (787696004, 150)],
#  788455007: [(706016001, 163),
#   (788455001, 159),
#   (610776002, 147),
#   (706016002, 128),
#   (706016003, 117),
#   (788455008, 113)],
#  810106001: [(664074001, 75),
#   (751471001, 74),
#   (783346001, 68),
#   (573716012, 63),
#   (579541001, 63),
#   (673677002, 59)],
#  810005002: [(706016001, 133),
#   (562245001, 99),
#   (706016003, 92),
#   (810005001, 88),
#   (562245018, 84),
#   (610776002, 82)],
#  810592001: [(179123001, 47),
#   (751471001, 37),
#   (706016001, 37),
#   (568601006, 36),
#   (663942009, 36),
#   (651369005, 33)],
#  640539013: [(706016001, 101),
#   (640539001, 90),
#   (158340001, 90),
#   (751471001, 84),
#   (399223001, 83),
#   (610776002, 80)],
#  790791002: [(507909001, 134),
#   (751471001, 127),
#   (790791003, 118),
#   (695632002, 110),
#   (372860001, 104),
#   (372860002, 94)],
#  805275001: [(610776002, 84),
#   (706016001, 83),
#   (781613006, 81),
#   (399223001, 67),
#   (673677002, 67),
#   (372860001, 60)],
#  556539016: [(556539003, 576),
#   (556539001, 496),
#   (156231001, 321),
#   (372860001, 302),
#   (556539011, 293),
#   (556539010, 285)],
#  830016001: [(706016001, 226),
#   (448509014, 170),
#   (610776002, 155),
#   (751471001, 151),
#   (156231001, 150),
#   (610776001, 136)],
#  537895001: [(678342001, 1188),
#   (537895002, 253),
#   (706016001, 240),
#   (561445005, 204),
#   (706016002, 161),
#   (562245001, 155)],
#  752814016: [(752814003, 297),
#   (751471001, 277),
#   (783346001, 188),
#   (706016001, 169),
#   (562245046, 168),
#   (610776002, 154)],
#  820563003: [(706016001, 311),
#   (820563001, 273),
#   (673677002, 228),
#   (820563007, 216),
#   (820563002, 205),
#   (759871002, 202)],
#  826492003: [(706016001, 367),
#   (706016002, 214),
#   (610776002, 213),
#   (826492001, 201),
#   (448509014, 176),
#   (673677002, 139)],
#  757303012: [(720125001, 968),
#   (706016001, 689),
#   (464297007, 550),
#   (740498001, 533),
#   (372860001, 528),
#   (730683001, 475)],
#  760084003: [(706016001, 1661),
#   (760084006, 1102),
#   (706016002, 889),
#   (706016003, 773),
#   (759871002, 717),
#   (719530003, 676)],
#  690936021: [(690936013, 497),
#   (690936023, 409),
#   (690936002, 355),
#   (690936003, 260),
#   (690936006, 226),
#   (690936001, 215)],
#  854701001: [(832018001, 52),
#   (778064003, 38),
#   (399256005, 36),
#   (695632001, 35),
#   (803757001, 34),
#   (372860001, 32)],
#  767153002: [(608776002, 55),
#   (673396002, 38),
#   (783346018, 36),
#   (452618001, 36),
#   (372860001, 35),
#   (372860002, 35)],
#  554598070: [(554598047, 449),
#   (554598001, 422),
#   (728162001, 314),
#   (554598065, 270),
#   (554598003, 262),
#   (189634001, 242),
#   (610776002, 241)],
#  610776082: [(610776001, 313),
#   (610776002, 310),
#   (610776028, 126),
#   (610776072, 123),
#   (554598001, 120),
#   (610776071, 109)],
#  750423010: [(608776002, 17),
#   (399256001, 17),
#   (750423001, 17),
#   (610776002, 17),
#   (610776001, 16),
#   (731608001, 15)],
#  751471022: [(751471001, 1264),
#   (751471027, 396),
#   (751471026, 380),
#   (751471021, 350),
#   (783346001, 316),
#   (751471033, 304)],
#  556539027: [(556539003, 172),
#   (556539001, 121),
#   (556539010, 113),
#   (372860001, 107),
#   (111593001, 80),
#   (706016001, 79),
#   (556539011, 78)],
#  895993002: [(895993001, 213),
#   (895993003, 133),
#   (895993004, 126),
#   (895993006, 74),
#   (806388002, 70),
#   (610776001, 69)],
#  841383003: [(841383002, 7036),
#   (572797002, 1001),
#   (565379002, 963),
#   (778064003, 922),
#   (610776001, 895),
#   (610776002, 679)],
#  690936002: [(690936003, 979),
#   (690936001, 750),
#   (690936006, 662),
#   (690936023, 488),
#   (690936013, 466),
#   (690936014, 407)],
#  816938002: [(816938004, 345),
#   (816938001, 218),
#   (859139002, 199),
#   (859139001, 180),
#   (695632002, 156),
#   (610776001, 139)],
#  706016029: [(706016001, 1373),
#   (706016002, 981),
#   (706016015, 798),
#   (706016003, 666),
#   (706016006, 352),
#   (706016004, 322)],
#  621381009: [(706016001, 1100),
#   (706016002, 862),
#   (621381012, 748),
#   (621381001, 700),
#   (621381016, 553),
#   (706016003, 415)],
#  723173006: [(723173001, 503),
#   (706016001, 342),
#   (723173004, 333),
#   (706016002, 215),
#   (759871002, 155),
#   (706016003, 154)],
#  662935001: [(706016001, 97),
#   (372860001, 72),
#   (637673005, 72),
#   (448509014, 72),
#   (759871002, 67),
#   (741356002, 67)],
#  638899002: [(567993015, 189),
#   (638899001, 111),
#   (646429003, 100),
#   (597918001, 91),
#   (567993016, 79),
#   (564786001, 76)],
#  625321003: [(372860001, 162),
#   (464297007, 109),
#   (156231001, 103),
#   (160442007, 94),
#   (706016001, 92),
#   (372860002, 91)],
#  634320007: [(634320003, 69),
#   (630116006, 69),
#   (160442007, 66),
#   (634009010, 56),
#   (759871002, 50),
#   (634320006, 49)],
#  678942016: [(678942001, 1631),
#   (678942002, 551),
#   (678942022, 414),
#   (678942011, 386),
#   (673677002, 348),
#   (591334019, 325)],
#  662344015: [(662344003, 177),
#   (695632002, 127),
#   (516000001, 127),
#   (778064003, 127),
#   (534210008, 107),
#   (695632001, 102)],
#  673638002: [(673638001, 364),
#   (673638005, 195),
#   (673677002, 134),
#   (591334003, 126),
#   (673638003, 125),
#   (673638007, 118)],
#  754910001: [(706016001, 276),
#   (562245001, 222),
#   (695632002, 202),
#   (754910002, 186),
#   (610776001, 182),
#   (762846001, 173)],
#  675068008: [(675068005, 218),
#   (675068001, 184),
#   (675068002, 150),
#   (706016001, 144),
#   (675068003, 138),
#   (610776001, 121)],
#  742912003: [(742916003, 4357),
#   (742912002, 840),
#   (742916002, 779),
#   (706016001, 267),
#   (742912001, 260),
#   (759871002, 254)],
#  742916003: [(742912003, 4357),
#   (742916002, 720),
#   (742912002, 704),
#   (706016001, 235),
#   (759871002, 224),
#   (742912001, 221)],
#  742916002: [(742912002, 3080),
#   (742912003, 779),
#   (742916003, 720),
#   (706016001, 409),
#   (559616001, 390),
#   (717884003, 372)],
#  742912002: [(742916002, 3080),
#   (742912003, 840),
#   (742916003, 704),
#   (742912001, 404),
#   (780636002, 360),
#   (620963002, 344)],
#  680318001: [(372860001, 303),
#   (464297007, 260),
#   (706016001, 231),
#   (372860002, 228),
#   (228257001, 224),
#   (160442007, 222)],
#  160442010: [(160442007, 19439),
#   (160442043, 5128),
#   (372860002, 1663),
#   (608776002, 1480),
#   (372860001, 1422),
#   (373506004, 1308)],
#  714345002: [(714345001, 86),
#   (706016001, 70),
#   (610776002, 59),
#   (610776001, 56),
#   (696542002, 49),
#   (562245001, 49)],
#  742747001: [(626168003, 20),
#   (228257001, 19),
#   (808029001, 17),
#   (372860001, 14),
#   (685816001, 14),
#   (786663001, 14),
#   (156231001, 13)],
#  715624010: [(706016001, 1172),
#   (706016002, 793),
#   (715624001, 663),
#   (759871002, 483),
#   (706016003, 458),
#   (610776002, 452)],
#  799853003: [(706016001, 176),
#   (706016002, 90),
#   (811761001, 77),
#   (759410006, 74),
#   (799853002, 72),
#   (802159001, 67)],
#  874035009: [(874035006, 52),
#   (706016001, 39),
#   (874035010, 38),
#   (796210001, 28),
#   (787696003, 26),
#   (843362003, 25)],
#  795440001: [(795440003, 1407),
#   (706016001, 1269),
#   (706016002, 870),
#   (610776002, 831),
#   (749699002, 727),
#   (749699001, 726)],
#  875272005: [(875272003, 150),
#   (706016001, 109),
#   (610776002, 86),
#   (711053003, 79),
#   (751471001, 71),
#   (399223001, 67)],
#  717490057: [(717490008, 896),
#   (717490010, 650),
#   (717490059, 620),
#   (610776002, 552),
#   (706016001, 526),
#   (717490058, 480)],
#  744703003: [(744703001, 85),
#   (706016001, 71),
#   (744703002, 65),
#   (749699002, 51),
#   (562245001, 46),
#   (751471001, 45)],
#  597891017: [(597891007, 191),
#   (741356002, 182),
#   (597891002, 141),
#   (706016001, 130),
#   (525518005, 116),
#   (706016002, 109)],
#  693764013: [(693764014, 129),
#   (693764002, 104),
#   (706016002, 77),
#   (771329016, 68),
#   (399223001, 61),
#   (745843002, 60)],
#  597891007: [(597891002, 931),
#   (741356002, 703),
#   (525518005, 439),
#   (706016001, 406),
#   (305304008, 345),
#   (612481002, 323)],
#  708352002: [(708352001, 392),
#   (708352004, 344),
#   (708352005, 263),
#   (706016001, 256),
#   (759871002, 193),
#   (372860001, 169)],
#  716959001: [(706016001, 30),
#   (674047003, 23),
#   (874891001, 22),
#   (228257001, 21),
#   (673396002, 17),
#   (695542005, 17)],
#  589222001: [(399223001, 2984),
#   (706016001, 2407),
#   (589222005, 2193),
#   (706016002, 1042),
#   (539723001, 787),
#   (562245001, 747)],
#  655784001: [(796210001, 1369),
#   (573716012, 1367),
#   (783346001, 1091),
#   (751471001, 1016),
#   (655784007, 1014),
#   (706016001, 925)],
#  746518001: [(759871002, 79),
#   (706016001, 73),
#   (448509014, 68),
#   (399223029, 58),
#   (692930001, 55),
#   (706016002, 52)],
#  763911001: [(763911002, 255),
#   (706016001, 81),
#   (562245001, 78),
#   (771733001, 71),
#   (673396002, 69),
#   (780048003, 62)],
#  616632001: [(673799001, 153),
#   (111586001, 152),
#   (706016001, 150),
#   (712587003, 147),
#   (599502001, 137),
#   (660712003, 135)],
#  718939002: [(718939001, 409),
#   (706016001, 185),
#   (718939005, 172),
#   (610776002, 164),
#   (610776001, 145),
#   (673677002, 141)],
#  761148001: [(706016001, 113),
#   (562245001, 91),
#   (562245046, 90),
#   (724942001, 57),
#   (719530003, 55),
#   (706016002, 55)],
#  719530003: [(706016001, 1977),
#   (719530004, 1099),
#   (706016002, 909),
#   (562245046, 740),
#   (706016003, 719),
#   (760084003, 676)],
#  725325002: [(598859001, 46),
#   (725332001, 44),
#   (744712001, 41),
#   (759871002, 37),
#   (739300001, 37),
#   (156231001, 35)],
#  699426003: [(600886001, 230),
#   (188183001, 229),
#   (699426001, 197),
#   (636505001, 191),
#   (595696024, 183),
#   (689109001, 182)],
#  711440001: [(706016001, 893),
#   (158340001, 447),
#   (711440004, 442),
#   (448509014, 439),
#   (706016002, 423),
#   (610776002, 415)],
#  568601006: [(568597006, 4845),
#   (568601007, 2098),
#   (751471001, 1917),
#   (507909001, 1914),
#   (706016001, 1800),
#   (573716012, 1447)],
#  763284006: [(763284004, 177),
#   (763284001, 129),
#   (774003001, 121),
#   (706016001, 115),
#   (752512006, 93),
#   (753737001, 92)],
#  752516003: [(752516005, 399),
#   (752516002, 275),
#   (706016001, 259),
#   (562245001, 218),
#   (753737001, 213),
#   (664319001, 191)],
#  731425002: [(706016001, 354),
#   (731425003, 316),
#   (448509014, 233),
#   (706016002, 212),
#   (731425001, 205),
#   (610776002, 197)],
#  749615004: [(706016001, 158),
#   (749615001, 135),
#   (706016002, 117),
#   (749615002, 111),
#   (599502001, 107),
#   (562245001, 107)],
#  736678002: [(706016001, 381),
#   (736678004, 273),
#   (804506001, 243),
#   (706016002, 235),
#   (759871002, 193),
#   (688537004, 186)],
#  753237003: [(562245001, 123),
#   (753237011, 100),
#   (610776002, 100),
#   (707743007, 94),
#   (753237002, 75),
#   (568601006, 73)],
#  800387001: [(706016001, 158),
#   (448509014, 120),
#   (706016002, 102),
#   (753737001, 97),
#   (759871002, 79),
#   (673677002, 77)],
#  716958001: [(716958002, 429),
#   (706016001, 355),
#   (716958003, 255),
#   (759871002, 231),
#   (706016002, 217),
#   (562245001, 215)],
#  790976006: [(790976002, 209),
#   (759871002, 163),
#   (706016001, 149),
#   (741356002, 113),
#   (603584018, 108),
#   (448509014, 107)],
#  722475006: [(507909024, 63),
#   (722475011, 61),
#   (722475005, 57),
#   (685816001, 54),
#   (562245001, 53),
#   (714032001, 53)],
#  722475011: [(565379001, 71),
#   (722475006, 61),
#   (722475005, 57),
#   (507910001, 47),
#   (618319002, 44),
#   (722475009, 42)],
#  722475016: [(706016001, 19),
#   (720504001, 16),
#   (722475007, 16),
#   (562245001, 15),
#   (588526002, 12),
#   (722475011, 11)],
#  739217001: [(711053003, 42),
#   (757926001, 33),
#   (220094010, 31),
#   (189634001, 22),
#   (573937001, 19),
#   (744285001, 18)],
#  719629009: [(685816001, 64),
#   (719629003, 36),
#   (372860002, 30),
#   (778064003, 26),
#   (719629001, 25),
#   (751471001, 23)],
#  688537021: [(684209027, 6030),
#   (688537004, 1202),
#   (688537011, 804),
#   (684209013, 790),
#   (684209004, 779),
#   (599580038, 767)],
#  684209027: [(688537021, 6030),
#   (688537004, 1353),
#   (684209004, 1211),
#   (684209013, 1182),
#   (688537001, 987),
#   (688537011, 963)],
#  456163026: [(706016001, 240),
#   (610776002, 148),
#   (706016002, 123),
#   (456163009, 110),
#   (448509014, 101),
#   (706016003, 94)],
#  579695004: [(579695005, 65),
#   (562245001, 30),
#   (673396002, 27),
#   (372860001, 27),
#   (562245046, 26),
#   (706016001, 24)],
#  850917001: [(507909001, 12225),
#   (501616007, 4246),
#   (507910001, 3244),
#   (850917003, 1051),
#   (568601006, 1026),
#   (751471001, 1013)],
#  748140003: [(748140001, 278),
#   (706016001, 133),
#   (748140002, 122),
#   (741356002, 103),
#   (706016002, 102),
#   (562245001, 88)],
#  721990004: [(723349001, 3913),
#   (692721002, 582),
#   (699453002, 569),
#   (721990006, 539),
#   (723349003, 531),
#   (699454002, 512)],
#  654854001: [(507909024, 46),
#   (355569001, 45),
#   (355569002, 41),
#   (507909023, 40),
#   (514577018, 35),
#   (572127013, 35)],
#  701600003: [(706016001, 21),
#   (610776001, 20),
#   (470985003, 15),
#   (720125001, 12),
#   (772005009, 12),
#   (695632002, 10),
#   (796210001, 9)],
#  ...}
